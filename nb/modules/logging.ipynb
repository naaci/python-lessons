# %% [markdown]
# <a href="https://colab.research.google.com/github/naaci/python-lessons/blob/main/nb/modules/logging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logging Error Messages

# %%
import logging
logging.basicConfig(
    filename="exceptions.log",
    level = logging.DEBUG,
    # level = logging.ERROR,
    force=True
)

logging.getLogger().isEnabledFor(logging.DEBUG)

# %%
try:
  a = []
  a[1]
except IndexError as err:
  logging.error(f"IndexError: {err}")
  # logging.warning(f"IndexError: {err}")
  # logging.info(f"IndexError: {err}")
  # logging.debug(f"IndexError: {err}")

# %%
logging.info("program started successfully")

# %%
logging.debug("some technical details" "and another")
